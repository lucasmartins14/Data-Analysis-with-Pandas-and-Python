# %%
import pandas as pd

# %%
chicago = pd.read_csv("C:/Users/Discover/Documents/LUCAS MARTINS/Python/Data Analysis with Pandas and Python/Datasets/chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1002.1+ KB

# %%
chicago["Department"].nunique()
# Out:
# 35

# %%
chicago.nunique()
# Out:
# Name                      31776
# Position Title             1093
# Department                   35
# Employee Annual Salary     1156
# dtype: int64

# %%
chicago["Department"] = chicago["Department"].astype("category")

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 784.2+ KB

# %% [markdown]
# # Métodos string - .lower() .upper() .title() .len()

# %%
chicago = pd.read_csv("C:/Users/Discover/Documents/LUCAS MARTINS/Python/Data Analysis with Pandas and Python/Datasets/chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago["Name"].str.lower()
# Out:
# 0            aaron,  elvia j
# 1          aaron,  jeffery m
# 2             aaron,  karina
# 3        aaron,  kimberlei r
# 4        abad jr,  vicente m
#                 ...
# 32058     zygowicz,  peter j
# 32059      zymantas,  mark e
# 32060    zyrkowski,  carlo e
# 32061    zyskowski,  dariusz
# 32062                    NaN
# Name: Name, Length: 32063, dtype: object

# %%
chicago["Name"].str.title()

chicago["Position Title"] = chicago["Position Title"].str.title()

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  Water Rate Taker  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    Police Officer       POLICE              $84450.00
# 2     AARON,  KARINA    Police Officer       POLICE              $84450.00

# %%
chicago["Department"].str.len()
# Out:
# 0        11.0
# 1         6.0
# 2         6.0
# 3        16.0
# 4        11.0
#          ...
# 32058     6.0
# 32059     6.0
# 32060     6.0
# 32061     4.0
# 32062     NaN
# Name: Department, Length: 32063, dtype: float64

# %% [markdown]
# # metodo .str.replace() substituição de uma string regular

# %%
chicago = pd.read_csv("C:/Users/Discover/Documents/LUCAS MARTINS/Python/Data Analysis with Pandas and Python/Datasets/chicago.csv").dropna(how = "all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
"Hello world".replace("l", "!")
# Out:
# 'He!!o wor!d'

# %%
chicago["Department"].str.replace("MGMNT", "MANAGEMENT")
chicago.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MANAGEMENT
# 1  AARON,  JEFFERY M    POLICE OFFICER            POLICE
# 2     AARON,  KARINA    POLICE OFFICER            POLICE
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0

# %%
chicago["Employee Annual Salary"] = chicago["Employee Annual Salary"].replace("$", "").astype(float)
chicago["Employee Annual Salary"].sum()
# Out:
# 2571506375.36

# %%
chicago["Employee Annual Salary"].nlargest(10)
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# 19208    195000.0
# 3706     187680.0
# 18556    187680.0
# 29466    187680.0
# 13754    185364.0
# Name: Employee Annual Salary, dtype: float64

# %% [markdown]
# # Filtrar com metodos string

# %%
chicago = pd.read_csv("C:/Users/Discover/Documents/LUCAS MARTINS/Python/Data Analysis with Pandas and Python/Datasets/chicago.csv").dropna(how = "all")
chicago["Department"] = chicago["Department"].astype("category")
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago["Position Title"].str.lower().str.contains("water")
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32057    False
# 32058    False
# 32059    False
# 32060    False
# 32061    False
# Name: Position Title, Length: 32062, dtype: bool
